# %%
import numpy as np

# %%
np.random.dirichlet((1, 1, 1), 10)
# Out:
# array([[0.54266514, 0.19526406, 0.26207081],
#        [0.86180593, 0.02330023, 0.11489383],
#        [0.08888762, 0.05617182, 0.85494055],
#        [0.48430323, 0.34558993, 0.17010684],
#        [0.09630418, 0.46658358, 0.43711224],
#        [0.31023125, 0.66329894, 0.02646982],
#        [0.19774878, 0.22136155, 0.58088967],
#        [0.66770071, 0.33112176, 0.00117753],
#        [0.72564996, 0.23122544, 0.04312459],
#        [0.03363013, 0.71229855, 0.25407133]])
